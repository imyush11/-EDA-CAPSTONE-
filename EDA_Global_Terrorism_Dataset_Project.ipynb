# %% [markdown]
# <a href="https://colab.research.google.com/github/imyush11/-EDA-CAPSTONE-/blob/main/EDA_Global_Terrorism_Dataset_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Author -** Imyush Shukla

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This is an Exploratory Data Analysis (EDA) project done for the purpose of analysis on the Global Terrorism dataset. Exploratory Data Analysis (EDA) is the process of looking closely at a dataset to identify its key features. It is an important element in the data science process since it may be used to find hidden patterns and insights in the data as well as potential problems with the data. Coming to the dataset part, The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland. The dataset contains a variety of details on terrorist attacks, such as the date, place, target, number of fatalities and injuries, and the kind of assault. This data can be used to spot patterns in terrorist activities, evaluate the effects of terrorism, and create plans to stop further attacks.
#
#
# This project is empty without the usage of the necessary libraries which includes Pandas which can be used to load the dataset into memory, clean the data, and perform basic statistical analysis. For example, using Pandas to calculate the number of terrorist attacks that occurred in each year, the number of people killed in terrorist attacks, and the type of attack that was most common. NumPy which can be used to perform more complex mathematical operations on the data. Like, using NumPy to calculate the correlation between the number of terrorist attacks and the number of people killed. Seaborn which can be used to create visualizations of the data whether showing the number of terrorist attacks by region or a line chart showing the number of people killed in terrorist attacks over time. Another visualization library, Matplotlib, which can also be used to create visualizations of the data.
#
# The main aim of this project is to find out about the various features that this dataset has and do some data wrangling and data visualization in order to gain some useful insights which may turn out to be beneficial for various reasons. By thoroughly analyzing these features, useful decisions can be made.
#
# In an overall sense, this project will perform an Exploratory Data Analysis and will go deep into this large dataset and will come up with some useful insights and information which can be highly advantageous in the context of understanding the world of terrorism and develop awareness of the same. The GTD is used in the EDA study mentioned in this summary to examine how terrorist activity is distributed by geography, attack style, year and more features. The initiative also looks on the correlation among various variables. The EDA's findings offer some insightful information about the nature of terrorism.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/imyush11/-EDA-CAPSTONE-.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The global terrorism dataset is a sizable and intricate dataset that includes details on terrorist attacks that have taken place globally since 1970. The dataset's vastness and complexity make it challenging to comprehend and analyse. The need for an exploratory data analysis (EDA) project to investigate the dataset and pinpoint significant discoveries is described in this problem statement. Insights from the EDA research will be utilised to build tactics for stopping future terrorist acts and to inform policy decisions.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Using the data to understand the nature of terrorism and develop tactics for averting future terrorist acts is the commercial goal for the global terrorism dataset. The information can be used to spot patterns in terrorist activities, evaluate the effects of terrorism, and create plans for stopping upcoming attacks. The conclusions drawn from the data analysis can be utilised to guide policy choices and create plans for stopping terrorist acts in the future.
#
# Using the global terrorism dataset for analysis, the following specific goals can be attained:
#
# - Number of terrorism throughout the years?
# - The most targeted group?
# - Number of Terrorist Activity by Region?
# - Top terrorists groups with highest number of terrorist activities?
# - Number of people killed due to terrorism?
# - Most Common Attack Types?
# - Any relationship among the features (Correlation) ?

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv("/content/drive/MyDrive/ALMA DATASET PROJECT/Global Terrorism Data.csv", encoding = "latin-1")
# Out:
# <ipython-input-3-16ab41884fbe>:2: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/ALMA DATASET PROJECT/Global Terrorism Data.csv", encoding = "latin-1")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
rows = df.shape[0]
columns = df.shape[1]
print(f"Number of rows = {rows} and number of columns = {columns}.")
# Out:
# Number of rows = 181691 and number of columns = 135.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df.isnull().sum()
# Out:
# eventid                    0
# iyear                      0
# imonth                     0
# iday                       0
# approxdate            172452
# extended                   0
# resolution            179471
# country                    0
# country_txt                0
# region                     0
# region_txt                 0
# provstate                421
# city                     434
# latitude                4556
# longitude               4557
# specificity                6
# vicinity                   0
# location              126196
# summary                66129
# crit1                      0
# crit2                      0
# crit3                      0
# doubtterr                  1
# alternative           152680
# alternative_txt       152680
# multiple                   1
# success                    0
# suicide                    0
# attacktype1                0
# attacktype1_txt            0
# attacktype2           175377
# attacktype2_txt       175377
# ...

# %%
# Visualizing the missing values
import missingno as msno

msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# After a first look at the dataset, it can be said that:
#
# A - **Features** - The dataset contains 181691 number of rows and 135 number of columns.
#
# B - **Memory Usage** - The data uses 187.1+ MB of memory.
#
# C - **Duplicate values** - The dataset does not contain any duplicate values.
#
# D - **Null Values** - The dataset contains various columns which have null values.
#
# E - **Data Types** - The dataset contains data types of Interger, Float and Object kind.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
columns = df.columns

for column in columns:
  print(column)
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# ...

# %%
# Dataset Describe
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **iyear** - This field contains the year in which the incident occurred.
#
# **imonth** - This field contains the number of the month in which the incident occurred.
#
# **iday** - This field contains the numeric day of the month on which the incident occurred.
#
# **country_txt** - This field identifies the country or location where the incident occurred.
#
# **attacktype1_txt**- This field captures the general method of attack and often reflects the broad class of tactics
# used.
#
# **region_txt**- This field identifies the region in which the incident occurred.
#
# **provstate** - This field identifies the state where the incident occurred.
#
# **targtype1_txt** - The target/victim type field captures the general type of target/victim.
#
# **target1** - This is the specific person, building, installation, etc., that was targeted and/or victimized.
#
# **nkill**- This field stores the number of total confirmed fatalities for the incident.
#
# **nwound** - This field records the number of confirmed non-fatal injuries to both perpetrators and victims.
#
# **gname**- This field contains the name of the group that carried out the attack.
#
# **motive** - When reports explicitly mention a specific motive for the attack, this motive is recorded in the
# “Motive” field.
#
# **weaptype1_txt** -  This field records the general type of
# weapon used in the incident.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df.nunique()
# Out:
# eventid               181691
# iyear                     47
# imonth                    13
# iday                      32
# approxdate              2244
# extended                   2
# resolution              1859
# country                  205
# country_txt              205
# region                    12
# region_txt                12
# provstate               2855
# city                   36674
# latitude               48322
# longitude              48039
# specificity                5
# vicinity                   3
# location               44109
# summary               112492
# crit1                      2
# crit2                      2
# crit3                      2
# doubtterr                  3
# alternative                5
# alternative_txt            5
# multiple                   2
# success                    2
# suicide                    2
# attacktype1                9
# attacktype1_txt            9
# attacktype2                9
# attacktype2_txt            9
# ...

# %%
# Checking unique values of a column (Example)
country_unique = df["country_txt"].unique()
print(country_unique)
# Out:
# ['Dominican Republic' 'Mexico' 'Philippines' 'Greece' 'Japan'
#  'United States' 'Uruguay' 'Italy' 'East Germany (GDR)' 'Ethiopia'
#  'Guatemala' 'Venezuela' 'West Germany (FRG)' 'Switzerland' 'Jordan'
#  'Spain' 'Brazil' 'Egypt' 'Argentina' 'Lebanon' 'Ireland' 'Turkey'
#  'Paraguay' 'Iran' 'United Kingdom' 'Colombia' 'Bolivia' 'Nicaragua'
#  'Netherlands' 'Belgium' 'Canada' 'Australia' 'Pakistan' 'Zambia' 'Sweden'
#  'Costa Rica' 'South Yemen' 'Cambodia' 'Israel' 'Poland' 'Taiwan' 'Panama'
#  'Kuwait' 'West Bank and Gaza Strip' 'Austria' 'Czechoslovakia' 'India'
#  'France' 'South Vietnam' 'Brunei' 'Zaire'
#  "People's Republic of the Congo" 'Portugal' 'Algeria' 'El Salvador'
#  'Thailand' 'Haiti' 'Sudan' 'Morocco' 'Cyprus' 'Myanmar' 'Afghanistan'
#  'Peru' 'Chile' 'Honduras' 'Yugoslavia' 'Ecuador' 'New Zealand' 'Malaysia'
#  'Singapore' 'Botswana' 'Jamaica' 'Chad' 'North Yemen' 'Andorra' 'Syria'
#  'South Korea' 'United Arab Emirates' 'South Africa' 'Kenya' 'Iraq'
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# Checking data types of the columns
datatypes = df.dtypes
print(datatypes)
# Out:
# eventid                 int64
# iyear                   int64
# imonth                  int64
# iday                    int64
# approxdate             object
# extended                int64
# resolution             object
# country                 int64
# country_txt            object
# region                  int64
# region_txt             object
# provstate              object
# city                   object
# latitude              float64
# longitude             float64
# specificity           float64
# vicinity                int64
# location               object
# summary                object
# crit1                   int64
# crit2                   int64
# crit3                   int64
# doubtterr             float64
# alternative           float64
# alternative_txt        object
# multiple              float64
# success                 int64
# suicide                 int64
# attacktype1             int64
# attacktype1_txt        object
# attacktype2           float64
# ...

# %%
# Renaming the required columns
df.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country","attacktype1_txt":"AttackType","region_txt":"Region","provstate":"State","targtype1_txt":"TargetGroup","target1":"Target","nkill":"Killed","nwound":"Wounded","gname":"GroupName","motive":"Motive","weaptype1_txt":"WeaponType"},inplace = True)

# %%
# Getting the specific dataset
tdf = df[["Year","Month","Day","Country","State","Region","AttackType","TargetGroup","Target","Killed","Wounded","GroupName","Motive","WeaponType"]]

# %%
# Showing the starting 5 rows of the dataset
tdf.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#                        AttackType                  TargetGroup  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                     Target  Killed  Wounded  \
# 0             Julio Guzman     1.0      0.0
# ...

# %%
# Dataset Information
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   State        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   AttackType   181691 non-null  object
#  7   TargetGroup  181691 non-null  object
#  8   Target       181055 non-null  object
#  9   Killed       171378 non-null  float64
#  10  Wounded      165380 non-null  float64
#  11  GroupName    181691 non-null  object
#  12  Motive       50561 non-null   object
#  13  WeaponType   181691 non-null  object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 19.4+ MB

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# There were many extra columns in the Global Terrorism Dataset. Only the essential and useful columns are chosen in our data wrangling process so that we may better grasp the dataset and acquire better and more insightful understandings throughout the subsequent visualisation phase. The primary alteration or manipulation in this case is, broadly speaking, the renaming and selection of the precise required columns from the dataset for the exploratory data analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# Creating a figure and setting the figure size
plt.figure(figsize=(25,8))

# Creating a count plot
sns.countplot(data=tdf, x="Year")

# Adding a title
plt.title("Number of terrorism throughout the years")

# Setting the rotation and fontsize of the xticks
plt.xticks(rotation = 75,fontsize=12)

# Showing the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because it is an easy and efficient approach to display the distribution of a categorical variable, a count plot is a viable option for this visualisation. The y-axis displays the count of events, and the count plot displays the number of terrorism incidents for each year. The year is on the x-axis, and to make it simpler to read, the x-ticks have been rotated.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart's conclusions are as follows:
#
#
# A - Over time, there have been more acts of terrorism, reaching a high in 2014.
#
# B - Although there have been fewer terrorist attacks in recent years, the threat of terrorism has not diminished.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# A - The count plot demonstrates that there have been more terrorist attacks in recent years. This is a negative trend since it shows that terrorism is getting worse. This might have a negative impact on businesses by increasing security expenses and reducing tourism.
#
# B - The count plot, however, also reveals that there have been years where there have been fewer acts of terrorism. This implies that it is possible to lessen the frequency of terrorist attacks and that companies can take precautions to limit the dangers.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Geting the data
targetgroup = df[df["TargetGroup"] != "Unknown"]

# Creating a figure and setting the figure size
plt.figure(figsize=(8,4))

# Creating a histogram
sns.histplot(data=targetgroup, x="TargetGroup")

# Adding a title
plt.title("The most targeted group")

# Setting the rotation and fontsize of the xticks
plt.xticks(rotation=75,fontsize=6)

# Showing the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A - The histogram chart was chosen because it is an effective tool for displaying data distribution. The TargetGroup column can be easily evaluated through this type of chart because it is a categorical variable.
#
# B - It can be used to evaluate how data are distributed among several categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights are as follows:
#
# A- In terrorist activities, civilians are the most frequently targeted group. Due to this, the fear among the people rises and hindrances in their daily working lifestyle.
#
# B - The Military and Police are the second and third highest targeted group respectively. Both of these groups are involved in protecting the people of the nation but are targeted by the terrorist groups almost equally to gain military power.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# A - Businesses which employs civilians in high-risk locations may want to think about offering them training on how to spot and prevent terrorist attacks. By doing this, they might be able to lessen the number of casualties and injuries in a terrorist assault.
#
# B - In context of negative growth, decline in tourism may result from people's reluctance to visit nations where there is a significant danger of terrorism due to the rise in terrorist strikes against civilian targets in recent years. Businesses that depend on tourists for revenue may suffer as a result.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Creating a figure and setting the figure size
plt.figure(figsize=(25,8))

# Creating a count plot
sns.countplot(data=tdf, x="Region")

# Adding a title
plt.title("Number of Terrorist Activity by Region")

# Setting the rotation of xticks
plt.xticks(rotation = 60)

# Showing the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The count plot is used because it is a useful tool for displaying how data are distributed. Because the region column is a categorical variable, the plot is utilised for visualization purpose and also, as it is possible to use it to visualise data with many different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights are as follows:
#
# A- The most terrorist activity is concentrated in the Middle East and North Africa (MENA) region, followed by South Asia and South America.
#
# B - Terrorist action is can be seen least in the East Asia region and the Central Asia region.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# A - Through better understanding of the dangers posed by terrorism and taking action to reduce those risks, businesses may benefit from the insights provided by the chart. Businesses operating in the MENA region, for instance, might want to think about offering their staff training on how to recognise and prevent future terrorist attacks. By doing this, they might be able to lessen the number of casualties and injuries in a terrorist assault.
#
# B - In context of negative growth, the fact that the MENA region experiences the highest levels of terrorist activity may cause tourism to decline since individuals may be less inclined to visit nations where there is a high risk of terrorism. Businesses that depend on tourists for revenue may suffer as a result.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Geting the data
GroupName = tdf[tdf["GroupName"] != "Unknown"]["GroupName"].value_counts().head(10)

# Creating a figure and setting the figure size
plt.figure(figsize=(25,6))

# Creating a bar plot
sns.barplot(data=tdf, x=GroupName.index, y=GroupName.values)

# Adding a title
plt.title("Top terrorists groups with highest number of terrorist activities")

# Setting the rotation and fontsize of the xticks
plt.xticks(rotation = 60,fontsize=12)

# Showing the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot was chosen since it is an effective tool for displaying how the data is distributed. The bar plot, which displays the distribution of terrorist activity by terrorist group, displays information about terrorist acts from the data set.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights found:
#
# The terrorist organisation with the most terrorist acts is the Taliban.
# ISIL, also known as the Islamic State of Iraq and the Levant, is the terrorist organisation that has committed the second-highest number of terrorist acts.
# The third terrorist organisation with the most terrorist acts is Shining Path.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# A - Businesses that conduct business in nations where these terrorist organisations are operating may wish to think about teaching their employees on how to deal with terrorist attacks. Through this, they might be prevent getting injured.
#
# B - In the negative growth area, Taliban is the terrorist organisation that has committed the most terrorist acts and this could result in fewer travel to nations where there is a high risk of terrorism because of these groups.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Creating figure and setting figure size
plt.figure(figsize=(8,4))

# Creating a line plot
sns.lineplot(data=tdf, x="Year",y="Killed", estimator = "sum")

# Adding a title
plt.title("Number of people killed due to terrorism")

# Showing the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The line plot was chosen because it provides a clear representation of the trends in the data over time. The line plot demonstrates the rise in terrorism-related fatalities over the past few years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The plot revealed the following insights:
#
# A - Terrorism has been responsible for an increase in the number of fatalities in recent years, the peak was in 2014 where the number of people killed was the highest.
#
# B - Although the number of fatalities has fallen recently, it is still high.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There are various negative impacts on the businesses like Decline in investment, Decline in tourism, Costlier security measures, Productivity loss and Loss of reputation due to the increaing killed trend due to terrorism.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Geting the data
attackdata = tdf[tdf["AttackType"]!= "Unknown"]["AttackType"].value_counts().head(6)

# Creating the pie chart
plt.pie(attackdata, labels=attackdata.index, autopct="%1.1f%%")

# Adding a title
plt.title("Most Common Attack Types")

# Showing the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart was chosen because it provides a clear picture of how the data is distributed. Pie charts are a useful tool for contrasting various elements of a whole for instance, the types of attacks can be easily interpreted via these type of charts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights found from the pie chart are:
#
# A - Bombing/Explosion is the most common attack type, accounting for 51.1% of all attacks.
#
# B - Armed Assault is the second most common attack type, accounting for 24.7% of all attacks.
#
# C - Other attack types, such as Assassination, Hostage Taking (Kidnapping), Facility/Infrastructure Attack makes up the rest of the percentage.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights helps the businesses with their processes like Investing in security measures, creating crisis management plans, and educating staff members about terrorism and all these actions are helpful for businesses in order to reduce the risks of terrorism and the type of common attacks that may happen.

# %% [markdown]
# #### Chart - 7 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Getting the data
correlation = tdf.corr()

# Creating a heatmap
sns.heatmap(correlation, annot=True)

# Adding a title
plt.title("Correlation Matrix")

# Showing the plot
plt.show()
# Out:
# <ipython-input-25-738d3f4a4672>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = tdf.corr()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The correlation heatmap was chosen because it provides a good way to visualize and reveal several significant correlations between the various variables in the data set. Businesses could find this information useful in understanding the risks of terrorism and in taking precautions to protect their staff.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The major insight found is that the variables are not much correlated in the dataset except for the Killed and Wounded column which are somewhat correlated but not that highly.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# After conducting an Exploratory Data Analysis on the Global Terrorism Dataset, there are various suggestions which can be provided to the client in order to maintain effectiveness and efficiency to achieve their respective business objective. Some of these recommendations or suggestions are as follows:
#
# A - The employees of the business should receive training on spotting and avoiding potential terrorist risks. By doing this, it might be able to lessen the number of casualties and injuries in a terrorist assault.
#
# B - Invest in security equipment like armed guards, metal detectors, and security cameras. This might aid in preventing terrorist assaults on workers and property.
#
# C - Create plans for crisis management. This might enable the client to react to terrorist strikes quickly and successfully.
#
# D - Inform workers about terrorism. This might make it easier for workers to recognise the dangers of terrorism and take preventative measures.
#
# These suggestions would assist the client in achieving their goal of lowering the risk of terrorist attacks while safeguarding its personnel and property.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Exploratory data analysis (EDA) is the process of looking closely at a dataset to identify its key features. Here, an exploratory data analysis (EDA) on the Global Terrorism dataset has been done which provided useful insights which can help the client in achieving the required business objectives as well as find some useful information regarding the features of the dataset.
#
# The EDA was performed with the help of the following libraries:
#
# Pandas: Used for data analysis and manipulation.
# NumPy: For array-based mathematical operations.
# Seaborn: For data visualization.
# Matplotlib: For data visualization.
# Missingno: For null value visualization.
#
# The EDA made the following discoveries:
#
# A - Terrorism has been the cause of large number of deaths in recent years.
#
# B - Although Terrorist activity is not distributed equally around the globe, some regions are Hotspots, where there is high number of terrorist activities.
#
# C - Bombing and Armed assault are among the most common types of attack.
#
# D - The number of killed and the number of injuries/woundede are positively correlated.
#
# E - Taliban has been known to be the most operating terrorist group in the recent years.
#
# F - Although the number of terrorist activities has declined after the year 2014, the danger is still high.
#
# To conclude, this EDA project can be used to gain a deeper understanding of data. By understanding the data, the client make more informed decisions.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
